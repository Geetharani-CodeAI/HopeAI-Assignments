# %%
import numpy as np
import matplotlib.pyplot
import pandas as pd

# %%
dataset = pd.read_csv("insurance_pre.csv")
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,dtype=int,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent = dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid =  {'criterion':['squared_error','absolute_error','friedman_mse','poisson'],
              'max_features':['none','sqrt','log2'],'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True,verbose = 3, n_jobs = -1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 22 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'none' instead.
#
# --------------------------------------------------------------------------------
# 18 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'none' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.70442257 0.63644163 0.67547974 0.64383549
#         nan        nan 0.63596951 0.63559614 0.65689173 0.68998531
#         nan        nan 0.68970669 0.59956928 0.67940296 0.65265518
#         nan        nan 0.67249    0.62346879 0.66916776 0.62290066]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['none', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
print(grid.best_params_)
re = grid.cv_results_
print(re)
# Out:
# {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}
# {'mean_fit_time': array([0.00457835, 0.00339928, 0.01742015, 0.0145978 , 0.01499758,
#        0.01439915, 0.00288363, 0.00359983, 0.04999757, 0.03879652,
#        0.04999695, 0.03439784, 0.00280032, 0.00280023, 0.01353607,
#        0.01239929, 0.01519866, 0.0115983 , 0.00300002, 0.00319967,
#        0.01999831, 0.01540003, 0.01739793, 0.01679769]), 'std_fit_time': array([0.00081661, 0.00079982, 0.00283642, 0.001356  , 0.00109467,
#        0.00101966, 0.0002322 , 0.00080047, 0.00576164, 0.00416739,
#        0.0037951 , 0.00355514, 0.00039976, 0.00040066, 0.00106512,
#        0.00249741, 0.00159965, 0.00080011, 0.00109571, 0.00040133,
#        0.00109476, 0.00445414, 0.00185548, 0.00248226]), 'mean_score_time': array([0.        , 0.        , 0.01019998, 0.00960016, 0.00899973,
#        0.00919943, 0.        , 0.        , 0.00980091, 0.00819964,
#        0.00759969, 0.00839944, 0.        , 0.        , 0.0073987 ,
#        0.00820017, 0.00959992, 0.00820088, 0.        , 0.        ,
#        0.00840034, 0.00699897, 0.00639992, 0.00759945]), 'std_score_time': array([0.        , 0.        , 0.0027864 , 0.00185557, 0.00089346,
#        0.00159987, 0.        , 0.        , 0.00239772, 0.00116557,
#        0.00079947, 0.00185502, 0.        , 0.        , 0.00102017,
#        0.00116724, 0.00332253, 0.00074756, 0.        , 0.        ,
#        0.00135647, 0.00063301, 0.00174299, 0.00162498]), 'param_criterion': masked_array(data=['squared_error', 'squared_error', 'squared_error',
#                    'squared_error', 'squared_error', 'squared_error',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'absolute_error', 'absolute_error', 'absolute_error',
#                    'friedman_mse', 'friedman_mse', 'friedman_mse',
#                    'friedman_mse', 'friedman_mse', 'friedman_mse',
#                    'poisson', 'poisson', 'poisson', 'poisson', 'poisson',
#                    'poisson'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_max_features': masked_array(data=['none', 'none', 'sqrt', 'sqrt', 'log2', 'log2', 'none',
#                    'none', 'sqrt', 'sqrt', 'log2', 'log2', 'none', 'none',
#                    'sqrt', 'sqrt', 'log2', 'log2', 'none', 'none', 'sqrt',
#                    'sqrt', 'log2', 'log2'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'param_splitter': masked_array(data=['best', 'random', 'best', 'random', 'best', 'random',
#                    'best', 'random', 'best', 'random', 'best', 'random',
#                    'best', 'random', 'best', 'random', 'best', 'random',
#                    'best', 'random', 'best', 'random', 'best', 'random'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'criterion': 'squared_error', 'max_features': 'none', 'splitter': 'best'}, {'criterion': 'squared_error', 'max_features': 'none', 'splitter': 'random'}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}, {'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'random'}, {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'best'}, {'criterion': 'squared_error', 'max_features': 'log2', 'splitter': 'random'}, {'criterion': 'absolute_error', 'max_features': 'none', 'splitter': 'best'}, {'criterion': 'absolute_error', 'max_features': 'none', 'splitter': 'random'}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'best'}, {'criterion': 'absolute_error', 'max_features': 'sqrt', 'splitter': 'random'}, {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'best'}, {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'random'}, {'criterion': 'friedman_mse', 'max_features': 'none', 'splitter': 'best'}, {'criterion': 'friedman_mse', 'max_features': 'none', 'splitter': 'random'}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'best'}, {'criterion': 'friedman_mse', 'max_features': 'sqrt', 'splitter': 'random'}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}, {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'random'}, {'criterion': 'poisson', 'max_features': 'none', 'splitter': 'best'}, {'criterion': 'poisson', 'max_features': 'none', 'splitter': 'random'}, {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'best'}, {'criterion': 'poisson', 'max_features': 'sqrt', 'splitter': 'random'}, {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'best'}, {'criterion': 'poisson', 'max_features': 'log2', 'splitter': 'random'}], 'split0_test_score': array([       nan,        nan, 0.76194568, 0.6645571 , 0.76673648,
#        0.65007865,        nan,        nan, 0.72545543, 0.70926532,
#        0.72048978, 0.71043248,        nan,        nan, 0.76882855,
#        0.59566323, 0.72828836, 0.64479053,        nan,        nan,
#        0.72017467, 0.60639551, 0.67120687, 0.61213036]), 'split1_test_score': array([       nan,        nan, 0.65110822, 0.62637641, 0.67923459,
#        0.49903897,        nan,        nan, 0.67728572, 0.39686218,
#        0.60231759, 0.57499498,        nan,        nan, 0.60599853,
#        0.42393489, 0.64863838, 0.63632227,        nan,        nan,
#        0.63275739, 0.58952045, 0.5670671 , 0.45064704]), 'split2_test_score': array([       nan,        nan, 0.64548187, 0.67021049, 0.74390832,
#        0.75423158,        nan,        nan, 0.40980066, 0.73355603,
#        0.61296621, 0.79573632,        nan,        nan, 0.69387632,
#        0.65634547, 0.67950155, 0.60930124,        nan,        nan,
#        0.60120314, 0.66520978, 0.71343555, 0.63054092]), 'split3_test_score': array([       nan,        nan, 0.750183  , 0.62410515, 0.712426  ,
#        0.67930345,        nan,        nan, 0.71323217, 0.70308868,
#        0.720032  , 0.65815408,        nan,        nan, 0.73201353,
#        0.66379287, 0.70295918, 0.66560196,        nan,        nan,
#        0.65523353, 0.65216037, 0.69774346, 0.69365461]), 'split4_test_score': array([       nan,        nan, 0.71339405, 0.596959  , 0.47509332,
#        0.63652481,        nan,        nan, 0.65407355, 0.63520849,
#        0.62865307, 0.71060871,        nan,        nan, 0.64781653,
#        0.65810994, 0.63762732, 0.70725988,        nan,        nan,
#        0.75308127, 0.60405786, 0.69638585, 0.7275304 ]), 'mean_test_score': array([       nan,        nan, 0.70442257, 0.63644163, 0.67547974,
#        0.64383549,        nan,        nan, 0.63596951, 0.63559614,
#        0.65689173, 0.68998531,        nan,        nan, 0.68970669,
#        0.59956928, 0.67940296, 0.65265518,        nan,        nan,
#        0.67249   , 0.62346879, 0.66916776, 0.62290066]), 'std_test_score': array([       nan,        nan, 0.0485795 , 0.02736125, 0.1044453 ,
#        0.08307073,        nan,        nan, 0.11590029, 0.12375183,
#        0.05241491, 0.0724744 ,        nan,        nan, 0.05801614,
#        0.09125559, 0.03357484, 0.03273369,        nan,        nan,
#        0.05608398, 0.02961854, 0.05281237, 0.09570704]), 'rank_test_score': array([17, 17,  1, 11,  5, 10, 17, 17, 12, 13,  8,  2, 17, 17,  3, 16,  4,
#         9, 17, 17,  6, 14,  7, 15])}

# %%
print("The best R_score value Parameters:{}".format(grid.best_params_))
# Out:
# The best R_score value Parameters:{'criterion': 'squared_error', 'max_features': 'sqrt', 'splitter': 'best'}

# %%
table = pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.004578      0.000817         0.000000        0.000000
# 1        0.003399      0.000800         0.000000        0.000000
# 2        0.017420      0.002836         0.010200        0.002786
# 3        0.014598      0.001356         0.009600        0.001856
# 4        0.014998      0.001095         0.009000        0.000893
# 5        0.014399      0.001020         0.009199        0.001600
# 6        0.002884      0.000232         0.000000        0.000000
# 7        0.003600      0.000800         0.000000        0.000000
# 8        0.049998      0.005762         0.009801        0.002398
# 9        0.038797      0.004167         0.008200        0.001166
# 10       0.049997      0.003795         0.007600        0.000799
# 11       0.034398      0.003555         0.008399        0.001855
# 12       0.002800      0.000400         0.000000        0.000000
# 13       0.002800      0.000401         0.000000        0.000000
# 14       0.013536      0.001065         0.007399        0.001020
# 15       0.012399      0.002497         0.008200        0.001167
# 16       0.015199      0.001600         0.009600        0.003323
# 17       0.011598      0.000800         0.008201        0.000748
# 18       0.003000      0.001096         0.000000        0.000000
# 19       0.003200      0.000401         0.000000        0.000000
# 20       0.019998      0.001095         0.008400        0.001356
# 21       0.015400      0.004454         0.006999        0.000633
# 22       0.017398      0.001855         0.006400        0.001743
# 23       0.016798      0.002482         0.007599        0.001625
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               none           best
# 1    squared_error               none         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               none           best
# 7   absolute_error               none         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               none           best
# 13    friedman_mse               none         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
# 18         poisson               none           best
# 19         poisson               none         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.761946
# 3   {'criterion': 'squared_error', 'max_features':...           0.664557
# 4   {'criterion': 'squared_error', 'max_features':...           0.766736
# 5   {'criterion': 'squared_error', 'max_features':...           0.650079
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.725455
# 9   {'criterion': 'absolute_error', 'max_features'...           0.709265
# 10  {'criterion': 'absolute_error', 'max_features'...           0.720490
# 11  {'criterion': 'absolute_error', 'max_features'...           0.710432
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.768829
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.595663
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.728288
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.644791
# 18  {'criterion': 'poisson', 'max_features': 'none...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'none...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.720175
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.606396
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.671207
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.612130
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.651108           0.645482           0.750183
# 3            0.626376           0.670210           0.624105
# 4            0.679235           0.743908           0.712426
# 5            0.499039           0.754232           0.679303
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.677286           0.409801           0.713232
# 9            0.396862           0.733556           0.703089
# 10           0.602318           0.612966           0.720032
# 11           0.574995           0.795736           0.658154
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.605999           0.693876           0.732014
# 15           0.423935           0.656345           0.663793
# 16           0.648638           0.679502           0.702959
# 17           0.636322           0.609301           0.665602
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.632757           0.601203           0.655234
# 21           0.589520           0.665210           0.652160
# 22           0.567067           0.713436           0.697743
# 23           0.450647           0.630541           0.693655
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.713394         0.704423        0.048579                1
# 3            0.596959         0.636442        0.027361               11
# 4            0.475093         0.675480        0.104445                5
# 5            0.636525         0.643835        0.083071               10
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.654074         0.635970        0.115900               12
# 9            0.635208         0.635596        0.123752               13
# 10           0.628653         0.656892        0.052415                8
# 11           0.710609         0.689985        0.072474                2
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.647817         0.689707        0.058016                3
# 15           0.658110         0.599569        0.091256               16
# 16           0.637627         0.679403        0.033575                4
# 17           0.707260         0.652655        0.032734                9
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.753081         0.672490        0.056084                6
# 21           0.604058         0.623469        0.029619               14
# 22           0.696386         0.669168        0.052812                7
# 23           0.727530         0.622901        0.095707               15

# %%
age = float(input("Age:"))
bmi = float(input("BMI:"))
children = float(input("Children:"))
sex_male = int(input("sex_male 0 or 1:"))
smoker_yes = int(input("smoker_yes 0 or 1"))
Future_Prediction = grid.predict([[age,bmi,children,sex_male,smoker_yes]])
print("Future_Prediction={}".format(Future_Prediction))
# Out:
# Age: 45
# BMI: 32
# Children: 2
# sex_male 0 or 1: 1
# smoker_yes 0 or 1 1
# Future_Prediction=[42760.5022]
# C:\Users\Hxtreme\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
